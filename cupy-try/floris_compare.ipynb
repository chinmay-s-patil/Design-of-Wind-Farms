# %%
import floris
import floris_cupy
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 import floris
# ----> 2 import floris_cupy
#
# File ~/Studies/Design of Wind Farms/modules/floris_cupy/floris_cupy/__init__.py:11
#       5 from pathlib import Path
#       8 __version__ = version("floris_cupy")
# ---> 11 from .floris_model import FlorisModel
#      12 from .flow_visualization import (
#      13     plot_rotor_values,
#      14     visualize_cut_plane,
#      15     visualize_quiver,
#      16 )
#      17 from .heterogeneous_map import HeterogeneousMap
#
# File ~/Studies/Design of Wind Farms/modules/floris_cupy/floris_cupy/floris_model.py:13
#      10 from floris_cupy._np_compat import np
#      11 import pandas as pd
# ---> 13 from floris_cupy.core import Core, State
#      14 from floris_cupy.core.rotor_velocity import average_velocity
# ...
